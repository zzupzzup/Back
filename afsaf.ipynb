# %%
import pandas as pd

test = pd.read_csv('/Users/hwangjaesung/Downloads/mango_user_04261723.csv')
test
# Out:
#        Unnamed: 0   nickname       title eval_user
# 0               0         준영     우동 이요이요       맛있다
# 1               1         준영         장꼬방       맛있다
# 2               2         준영          헤키       맛있다
# 3               3         준영  길버트버거앤프라이즈       맛있다
# 4               4         준영         다로베       맛있다
# ...           ...        ...         ...       ...
# 31889       31889        gom    옥수동 화덕피자       맛있다
# 31890       31890  guilietta        콴안다오       맛있다
# 31891       31891    ha park       캔프 치킨       맛있다
# 31892       31892     hailie        메종엠오       맛있다
# 31893       31893        ￦on        따띠따띠       NaN
#
# [31894 rows x 4 columns]

# %%
test = test.rename(columns={'Unnamed: 0':'id'})

# %%
test = test.rename(columns={'title':'store'})

# %%
test.drop(columns='id', inplace=True)

# %%
test.to_csv('/Users/hwangjaesung/Downloads/mango_user_04261723.csv', index = True)

# %%
import pandas as pd

test2 = pd.read_csv('/Users/hwangjaesung/Downloads/save_table_0429_1525.csv')
test2
# Out:
#      Unnamed: 0   title  Point     View  Review   Star  \
# 0           118     램랜드    4.3   49,465      34  1,324
# 1           136   청춘구락부    4.3   14,857      11    199
# 2           138     장꼬방    4.1  143,704     154  3,694
# 3           192  프로간장게장    4.0  121,224     101  2,464
# 4           195   진동둔횟집    4.0   19,085      20    270
# ..          ...     ...    ...      ...     ...    ...
# 792         195    도치피자    3.2   27,993      32    546
# 793         196    은호초밥    3.2    9,907      42    101
# 794         198   육회한연어    3.2    7,961      11     43
# 795         199    메차쿠차    3.2   16,540      15    155
# 796         163      얹다    3.7    2,701       8     51
#
#                          Address  \
# 0             서울시 마포구 용강동 494-32
# 1               서울시 마포구 용강동 50-4
# 2               서울시 서초구 서초동 1316
# 3          서울시 서초구 잠원동 27-1 프로빌딩
# 4              서울시 서초구 잠원동 36-18
# ..                           ...
# 792           서울시 광진구 구의동 218-10
# ...

# %%
#test2.reset_index(inplace=True)

# %%
test2
# Out:
#      Unnamed: 0   title  Point     View  Review   Star  \
# 0           118     램랜드    4.3   49,465      34  1,324
# 1           136   청춘구락부    4.3   14,857      11    199
# 2           138     장꼬방    4.1  143,704     154  3,694
# 3           192  프로간장게장    4.0  121,224     101  2,464
# 4           195   진동둔횟집    4.0   19,085      20    270
# ..          ...     ...    ...      ...     ...    ...
# 792         195    도치피자    3.2   27,993      32    546
# 793         196    은호초밥    3.2    9,907      42    101
# 794         198   육회한연어    3.2    7,961      11     43
# 795         199    메차쿠차    3.2   16,540      15    155
# 796         163      얹다    3.7    2,701       8     51
#
#                          Address  \
# 0             서울시 마포구 용강동 494-32
# 1               서울시 마포구 용강동 50-4
# 2               서울시 서초구 서초동 1316
# 3          서울시 서초구 잠원동 27-1 프로빌딩
# 4              서울시 서초구 잠원동 36-18
# ..                           ...
# 792           서울시 광진구 구의동 218-10
# ...

# %%
test2.drop(columns='Unnamed: 0', inplace=True)

# %%
test2
# Out:
#       title  Point     View  Review   Star                      Address  \
# 0       램랜드    4.3   49,465      34  1,324           서울시 마포구 용강동 494-32
# 1     청춘구락부    4.3   14,857      11    199             서울시 마포구 용강동 50-4
# 2       장꼬방    4.1  143,704     154  3,694             서울시 서초구 서초동 1316
# 3    프로간장게장    4.0  121,224     101  2,464        서울시 서초구 잠원동 27-1 프로빌딩
# 4     진동둔횟집    4.0   19,085      20    270            서울시 서초구 잠원동 36-18
# ..      ...    ...      ...     ...    ...                          ...
# 792    도치피자    3.2   27,993      32    546           서울시 광진구 구의동 218-10
# 793    은호초밥    3.2    9,907      42    101             서울시 광진구 자양동 7-22
# 794   육회한연어    3.2    7,961      11     43            서울시 광진구 화양동 49-13
# 795    메차쿠차    3.2   16,540      15    155            서울시 광진구 구의동 593-9
# 796      얹다    3.7    2,701       8     51  서울시 마포구 연남동 383-82 신박사빌딩 2F
#
#                                                   Type    Price  Parking  \
# ...

# %%
#test2
#(id, store, point, view, review, star, address, type, price, parking, opening, breaktime, dayoff, address_gu, category, main_food);

test2.columns = ['store', 'point', 'view', 'review', 'star', 'address', 'food_type', 'price', 'parking', 'opening', 'breaktime', 'dayoff', 'address_gu', 'category', 'main_food'];

# %%
#test2.rename(columns={'index':'id'}, inplace=True)

# %%
test2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 797 entries, 0 to 796
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   store       797 non-null    object
#  1   point       797 non-null    float64
#  2   view        797 non-null    object
#  3   review      797 non-null    int64
#  4   star        797 non-null    object
#  5   address     797 non-null    object
#  6   food_type   797 non-null    object
#  7   price       779 non-null    object
#  8   parking     658 non-null    object
#  9   opening     656 non-null    object
#  10  breaktime   284 non-null    object
#  11  dayoff      119 non-null    object
#  12  address_gu  797 non-null    object
#  13  category    797 non-null    object
#  14  main_food   797 non-null    object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 93.5+ KB

# %%
test2
# Out:
#       store  point     view  review   star                      address  \
# 0       램랜드    4.3   49,465      34  1,324           서울시 마포구 용강동 494-32
# 1     청춘구락부    4.3   14,857      11    199             서울시 마포구 용강동 50-4
# 2       장꼬방    4.1  143,704     154  3,694             서울시 서초구 서초동 1316
# 3    프로간장게장    4.0  121,224     101  2,464        서울시 서초구 잠원동 27-1 프로빌딩
# 4     진동둔횟집    4.0   19,085      20    270            서울시 서초구 잠원동 36-18
# ..      ...    ...      ...     ...    ...                          ...
# 792    도치피자    3.2   27,993      32    546           서울시 광진구 구의동 218-10
# 793    은호초밥    3.2    9,907      42    101             서울시 광진구 자양동 7-22
# 794   육회한연어    3.2    7,961      11     43            서울시 광진구 화양동 49-13
# 795    메차쿠차    3.2   16,540      15    155            서울시 광진구 구의동 593-9
# 796      얹다    3.7    2,701       8     51  서울시 마포구 연남동 383-82 신박사빌딩 2F
#
#                                              food_type    price  parking  \
# ...

# %%
test2.to_csv('/Users/hwangjaesung/Downloads/save_table_0429_1525.csv', index = True)

# %%
import pandas as pd 

test3 = pd.read_csv('/Users/hwangjaesung/Downloads/user_0507.csv', )
test3
# Out:
#      1  active    test@example.com  \
# 0    2  active   test1@example.com
# 1    3  active   test2@example.com
# 2    4  active   test3@example.com
# 3    5  active   test4@example.com
# 4    6  active   test5@example.com
# 5    7  active   test6@example.com
# 6    8  active   test7@example.com
# 7    9  active   test8@example.com
# 8   10  active   test9@example.com
# 9   11  active  test10@example.com
# 10  12  active  test11@example.com
# 11  13  active  test12@example.com
#
#    $2b$12$xjcxSG1fapxvkURbbmtbBedTlxwvjpJtyHqVCaymPLGbEkZ.fihyW  준영  24  man  \
# 0   $2b$12$LURF07027GL5MnSYCRgSpO9q7xZdwJjldx4Ysq1...            재성  27   \N
# 1   $2b$12$mtDWVy0EaKrvZXvsZS.uHOFXlT7lwPyQub.BdL5...            재성  27  man
# 2   $2b$12$BCHDaL8AosLNIehuOuu0RuC03PVdKtDb6RiSM2b...            승현  23  man
# 3   $2b$12$ehshqQAanM7nxoO/Oyyav.a9qwZ2f3rQTCdv2AS...            재성  28  man
# 4   $2b$12$.fZQqwO.QDUO6RnLO76gIOlZDjKO4VvjeD4H7An...            승현  26  man
# ...

# %%
test3.columns = ['id', 'status', 'email', 'pw', 'nickname', 'age', 'gender', 'store', 'category', 'sns_type', 'updated_at', 'created_at']

# %%
test3.drop(columns='id')
# Out:
#     id  status               email  \
# 0    2  active   test1@example.com
# 1    3  active   test2@example.com
# 2    4  active   test3@example.com
# 3    5  active   test4@example.com
# 4    6  active   test5@example.com
# 5    7  active   test6@example.com
# 6    8  active   test7@example.com
# 7    9  active   test8@example.com
# 8   10  active   test9@example.com
# 9   11  active  test10@example.com
# 10  12  active  test11@example.com
# 11  13  active  test12@example.com
#
#                                                    pw nickname  age gender  \
# 0   $2b$12$LURF07027GL5MnSYCRgSpO9q7xZdwJjldx4Ysq1...       재성   27     \N
# 1   $2b$12$mtDWVy0EaKrvZXvsZS.uHOFXlT7lwPyQub.BdL5...       재성   27    man
# 2   $2b$12$BCHDaL8AosLNIehuOuu0RuC03PVdKtDb6RiSM2b...       승현   23    man
# 3   $2b$12$ehshqQAanM7nxoO/Oyyav.a9qwZ2f3rQTCdv2AS...       재성   28    man
# 4   $2b$12$.fZQqwO.QDUO6RnLO76gIOlZDjKO4VvjeD4H7An...       승현   26    man
# ...

# %%
test3.to_csv('/Users/hwangjaesung/Downloads/user_0507.csv', index = True)

# %%
import pandas as pd 

test3 = pd.read_csv('/Users/hwangjaesung/Downloads/user_0507.csv', )
test3
# Out:
#     Unnamed: 0  id  status               email  \
# 0            0   2  active   test1@example.com
# 1            1   3  active   test2@example.com
# 2            2   4  active   test3@example.com
# 3            3   5  active   test4@example.com
# 4            4   6  active   test5@example.com
# 5            5   7  active   test6@example.com
# 6            6   8  active   test7@example.com
# 7            7   9  active   test8@example.com
# 8            8  10  active   test9@example.com
# 9            9  11  active  test10@example.com
# 10          10  12  active  test11@example.com
# 11          11  13  active  test12@example.com
#
#                                                    pw nickname  age gender  \
# 0   $2b$12$LURF07027GL5MnSYCRgSpO9q7xZdwJjldx4Ysq1...       재성   27     \N
# 1   $2b$12$mtDWVy0EaKrvZXvsZS.uHOFXlT7lwPyQub.BdL5...       재성   27    man
# 2   $2b$12$BCHDaL8AosLNIehuOuu0RuC03PVdKtDb6RiSM2b...       승현   23    man
# ...

# %%
import pandas as pd 

test4 = pd.read_csv('/Users/hwangjaesung/Downloads/store_0507_1614.csv', index_col=0)
test4
# Out:
#               store  point    view  review  star  \
# 0               램랜드    4.3   49465      34  1324
# 1             청춘구락부    4.3   14857      11   199
# 2               장꼬방    4.1  143704     154  3694
# 3            프로간장게장    4.0  121224     101  2464
# 4             진동둔횟집    4.0   19085      20   270
# ...             ...    ...     ...     ...   ...
# 1137  곳 온니 플레이스 성수점    4.3      20       3    56
# 1138            로우키    4.1     130      12    56
# 1139          치카이라멘    4.6     260       5    56
# 1140          한우일번지    5.0      30       2    56
# 1141           대성갈비    3.4    4810      25    56
#
#                               address food_type    join_key  \
# 0                  서울시 마포구 용강동 494-32        한식         램랜드
# 1                    서울시 마포구 용강동 50-4        한식       청춘구락부
# 2                    서울시 서초구 서초동 1316        한식         장꼬방
# 3               서울시 서초구 잠원동 27-1 프로빌딩        한식      프로간장게장
# 4                   서울시 서초구 잠원동 36-18        일식       진동둔횟집
# ...

# %%
test4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1142 entries, 0 to 1141
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     1142 non-null   object
#  1   Point     1142 non-null   float64
#  2   View      1142 non-null   int64
#  3   Review    1142 non-null   int64
#  4   Star      1142 non-null   int64
#  5   Address   1142 non-null   object
#  6   업태명       1142 non-null   object
#  7   join_key  1142 non-null   object
#  8   menu      1142 non-null   object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 80.4+ KB

# %%
test4
# Out:
#               title  Point    View  Review  Star  \
# 0               램랜드    4.3   49465      34  1324
# 1             청춘구락부    4.3   14857      11   199
# 2               장꼬방    4.1  143704     154  3694
# 3            프로간장게장    4.0  121224     101  2464
# 4             진동둔횟집    4.0   19085      20   270
# ...             ...    ...     ...     ...   ...
# 1137  곳 온니 플레이스 성수점    4.3      20       3    56
# 1138            로우키    4.1     130      12    56
# 1139          치카이라멘    4.6     260       5    56
# 1140          한우일번지    5.0      30       2    56
# 1141           대성갈비    3.4    4810      25    56
#
#                               Address       업태명    join_key  \
# 0                  서울시 마포구 용강동 494-32        한식         램랜드
# 1                    서울시 마포구 용강동 50-4        한식       청춘구락부
# 2                    서울시 서초구 서초동 1316        한식         장꼬방
# 3               서울시 서초구 잠원동 27-1 프로빌딩        한식      프로간장게장
# 4                   서울시 서초구 잠원동 36-18        일식       진동둔횟집
# ...

# %%
test4.columns= ['store','point','view','review','star','address','category','join_key','menu']

# %%
test4
# Out:
#               store  point    view  review  star  \
# 0               램랜드    4.3   49465      34  1324
# 1             청춘구락부    4.3   14857      11   199
# 2               장꼬방    4.1  143704     154  3694
# 3            프로간장게장    4.0  121224     101  2464
# 4             진동둔횟집    4.0   19085      20   270
# ...             ...    ...     ...     ...   ...
# 1137  곳 온니 플레이스 성수점    4.3      20       3    56
# 1138            로우키    4.1     130      12    56
# 1139          치카이라멘    4.6     260       5    56
# 1140          한우일번지    5.0      30       2    56
# 1141           대성갈비    3.4    4810      25    56
#
#                               address  category    join_key  \
# 0                  서울시 마포구 용강동 494-32        한식         램랜드
# 1                    서울시 마포구 용강동 50-4        한식       청춘구락부
# 2                    서울시 서초구 서초동 1316        한식         장꼬방
# 3               서울시 서초구 잠원동 27-1 프로빌딩        한식      프로간장게장
# 4                   서울시 서초구 잠원동 36-18        일식       진동둔횟집
# ...

# %%
test4.to_csv('/Users/hwangjaesung/Downloads/store_0507_1614.csv', index = True)

# %%
import pandas as pd 

test5 = pd.read_csv('/Users/hwangjaesung/Downloads/review_0510_1655.csv', index_col=0)
test5
# Out:
#            nickname                                         reviewtext  \
# title
# 오코노미야키식당하나    내일도먹음  이 가격으로 일본을 다녀올 수 있다구요⁉️\n오코노미야끼, 타코야끼 처돌이인 낼먹이...
# 오코노미야키식당하나       규릐  화양동에 위치한 오코노미야키 맛집!\n지하철역은 그나마 어린이대공원역이 가까운 듯?...
# 오코노미야키식당하나      미동이               맛있는데.. 물린다..!\n식사보다 2차 술집에 있었으면 하는..
# 오코노미야키식당하나       서머  이날 사진이 망해버려가지고.. ㅎ\n\n아무튼 오코노미야끼식당하나는 오코노미야끼 맛...
# 오코노미야키식당하나    용인불주먹  인생 첫 오코노미야키, 야끼소바!\n따로 보면 그리 특별한 재료들은 아닌데 철판에 ...
# ...             ...                                                ...
# 호호식당            NaN           아기자기 인테리어가 예뻤지만 테이블간 거리가 정말 좁은편이여서 아쉬웠어요
# 호호식당            NaN               맛있어요 근데 특별한정도의 맛있음 아니고그냥 맛있어요분위기가좋아요
# 호호식당            NaN           대학로에 본점인데 분점이 생겼나봐요웨이팅 시스템 있고 사케동이 유명합니다
# 호호식당            NaN               내부가 너무 아기자기하고 직원분들 정말 친절해요 음식도 괜찮습니다
# 호호식당            NaN                   음식 진짜 맛있어요 대기가 조금 있지만 금방 앉을수 있어요
#
#                                                          text
# title
# ...

# %%
test5.reset_index(inplace=True)

# %%
test5
# Out:
#             title nickname                                         reviewtext  \
# 0      오코노미야키식당하나    내일도먹음  이 가격으로 일본을 다녀올 수 있다구요⁉️\n오코노미야끼, 타코야끼 처돌이인 낼먹이...
# 1      오코노미야키식당하나       규릐  화양동에 위치한 오코노미야키 맛집!\n지하철역은 그나마 어린이대공원역이 가까운 듯?...
# 2      오코노미야키식당하나      미동이               맛있는데.. 물린다..!\n식사보다 2차 술집에 있었으면 하는..
# 3      오코노미야키식당하나       서머  이날 사진이 망해버려가지고.. ㅎ\n\n아무튼 오코노미야끼식당하나는 오코노미야끼 맛...
# 4      오코노미야키식당하나    용인불주먹  인생 첫 오코노미야키, 야끼소바!\n따로 보면 그리 특별한 재료들은 아닌데 철판에 ...
# ...           ...      ...                                                ...
# 34220        호호식당      NaN           아기자기 인테리어가 예뻤지만 테이블간 거리가 정말 좁은편이여서 아쉬웠어요
# 34221        호호식당      NaN               맛있어요 근데 특별한정도의 맛있음 아니고그냥 맛있어요분위기가좋아요
# 34222        호호식당      NaN           대학로에 본점인데 분점이 생겼나봐요웨이팅 시스템 있고 사케동이 유명합니다
# 34223        호호식당      NaN               내부가 너무 아기자기하고 직원분들 정말 친절해요 음식도 괜찮습니다
# 34224        호호식당      NaN                   음식 진짜 맛있어요 대기가 조금 있지만 금방 앉을수 있어요
#
# ...

# %%
test5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34225 entries, 0 to 34224
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   title       34225 non-null  object
#  1   nickname    25628 non-null  object
#  2   reviewtext  34225 non-null  object
#  3   text        34225 non-null  object
# dtypes: object(4)
# memory usage: 1.0+ MB

# %%
test5.columns = ['store', 'nickname', 'reviewtext', 'text']

# %%
test5.to_csv('/Users/hwangjaesung/Downloads/review_0510_1655.csv', index = True)
